# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.insert(0, "../")
import warnings
warnings.filterwarnings('ignore')

# %%
from quantumnetworks import DoubleModeSystem, plot_evolution
import numpy as np

# %%
A_in = lambda t: 0
B_in = lambda t: 0
sys = DoubleModeSystem(params={},A_in = A_in)
x_0 = np.array([1,0,0,1])
ts = np.linspace(0, 10, 1001)
X = sys.forward_euler(x_0, ts)
fig, ax = plot_evolution(X[0,:], ts, label="$q_a$")
plot_evolution(X[1,:], ts, fig=fig, ax=ax, label="$p_a$")
plot_evolution(X[2,:], ts, fig=fig, ax=ax, label="$q_b$")
plot_evolution(X[3,:], ts, fig=fig, ax=ax, label="$p_b$")
ax.legend()

# %%
#default A_in, B_in is used
sys = DoubleModeSystem(params={})
x_0 = np.array([0,0,0,0])
ts = np.linspace(0, 10, 1001)
X = sys.forward_euler(x_0, ts)
fig, ax = plot_evolution(X[0,:], ts, label="$q_a$")
plot_evolution(X[1,:], ts, fig=fig, ax=ax, label="$p_a$")
plot_evolution(X[2,:], ts, fig=fig, ax=ax, label="$q_b$")
plot_evolution(X[3,:], ts, fig=fig, ax=ax, label="$p_b$")
ax.legend()

# %%
u = sys.eval_u(0)
sys.eval_Jf(x_0, u)
# Out:
# array([[ 5.0e-04,  1.0e+00,  0.0e+00,  2.0e-03],
#        [-1.0e+00,  5.0e-04, -2.0e-03,  0.0e+00],
#        [ 0.0e+00,  2.0e-03,  2.5e-03,  2.0e+00],
#        [-2.0e-03,  0.0e+00, -2.0e+00,  2.5e-03]])

# %%
sys.eval_Jf_numerical(x_0, u)
# Out:
# array([[ 5.0e-04,  1.0e+00,  0.0e+00,  2.0e-03],
#        [-1.0e+00,  5.0e-04, -2.0e-03,  0.0e+00],
#        [ 0.0e+00,  2.0e-03,  2.5e-03,  2.0e+00],
#        [-2.0e-03,  0.0e+00, -2.0e+00,  2.5e-03]])
