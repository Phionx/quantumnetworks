# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.insert(0, "../")
import warnings
warnings.filterwarnings('ignore')

# %%
from quantumnetworks import SingleModeSystem, plot_evolution
import numpy as np

# %%
sys = SingleModeSystem(params={"omega_a": 1, "kappa_a": 0.001})
x_0 = np.array([0,0])
ts = np.linspace(0, 10, 1001)
X = sys.forward_euler(x_0, ts)
fig, ax = plot_evolution(X[0,:], ts, label="$q_a$")
plot_evolution(X[1,:], ts, fig=fig, ax=ax, label="$p_a$")
ax.legend()

# %%
u = sys.eval_u(0)
sys.eval_Jf(x_0, u)
# Out:
# array([[ 5.e-04,  1.e+00],
#        [-1.e+00,  5.e-04]])

# %%
sys.eval_Jf_numerical(x_0, u)
# Out:
# array([[ 5.e-04,  1.e+00],
#        [-1.e+00,  5.e-04]])
