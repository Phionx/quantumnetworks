# %%
# %load_ext autoreload
# %autoreload 2

# %%
from quantumnetworks import MultiModeSystem, plot_full_evolution
import numpy as np

# %%
# params directly provided
omegas = [1,2]
kappas = [0.001,0.005]
gammas = [0.002,0.002]
kerrs = [0.001, 0.001]
couplings = [[0,1,0.002]]
sys = MultiModeSystem(params={"omegas":omegas, "kappas":kappas, "gammas":gammas, "kerrs": kerrs, "couplings":couplings})
x_0 = np.array([1,0,0,1])
ts = np.linspace(0, 10, 1001)
print(10/1000)
# Out:
# 0.01

# %%
X = sys.trapezoidal(x_0, ts)

# %%
fig, ax = plot_full_evolution(X, ts, labels=["$q_a$","$p_a$","$q_b$","$p_b$"])
ax.set_xlim([0,6])
ax.legend()

# %%
X_dynamic, ts_dynamic = sys.trapezoidal(x_0, ts, dynamic_dt=True)
# Out:
# dt increase:  0.02
# dt increase:  0.04
# dt increase:  0.08
# dt increase:  0.16
# dt increase:  0.32
# dt decrease:  0.16
# dt decrease:  0.08
# dt decrease:  0.04
# dt decrease:  0.02
# dt decrease:  0.01
# dt decrease:  0.005
# dt decrease:  0.0025
# dt decrease:  0.00125
# dt decrease:  0.000625
# dt decrease:  0.0003125
# dt increase:  0.000625
# dt increase:  0.00125
# dt increase:  0.0025
# dt increase:  0.005
# dt increase:  0.01
# dt increase:  0.02
# dt increase:  0.04
# dt increase:  0.08
# dt increase:  0.16
# dt increase:  0.32
# dt increase:  0.64
# dt decrease:  0.32
# dt decrease:  0.16
# dt decrease:  0.08
# dt increase:  0.16
# dt increase:  0.32
# dt increase:  0.64
# dt decrease:  0.32
# dt decrease:  0.16
# dt decrease:  0.08
# dt increase:  0.16
# dt increase:  0.32
# dt increase:  0.64

# %%
fig, ax = plot_full_evolution(X_dynamic, ts_dynamic, labels=["$q_a$","$p_a$","$q_b$","$p_b$"])
ax.set_xlim([0,6])
ax.legend()

# %% [markdown]
# Dynamic stepping is slower.
